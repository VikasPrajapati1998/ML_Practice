# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../data/csvData/mission_launches.csv")
df.head(20)
# Out:
#    Organisation                                           Location  \
# 0        SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1          CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2        SpaceX                      Pad A, Boca Chica, Texas, USA
# 3     Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# 5          CASC       LC-9, Taiyuan Satellite Launch Center, China
# 6     Roscosmos         Site 31/6, Baikonur Cosmodrome, Kazakhstan
# 7          CASC    LC-101, Wenchang Satellite Launch Center, China
# 8        SpaceX           SLC-40, Cape Canaveral AFS, Florida, USA
# 9          JAXA             LA-Y1, Tanegashima Space Center, Japan
# 10     Northrop      LP-0B, Wallops Flight Facility, Virginia, USA
# 11       ExPace    Site 95, Jiuquan Satellite Launch Center, China
# 12         CASC       LC-3, Xichang Satellite Launch Center, China
# ...

# %% [markdown]
# ### **pd.crosstab()**

# %%
pd.crosstab(df.Organisation, df.Mission_Status)
# Out:
# Mission_Status    Failure  Partial Failure  Prelaunch Failure  Success
# Organisation
# AEB                     2                0                  1        0
# AMBA                    3                1                  0        4
# ASI                     0                0                  0        9
# Arianespace             7                3                  0      269
# Arm??e de l'Air         0                1                  0        3
# Blue Origin             0                0                  0       12
# Boeing                  3                2                  0      131
# CASC                   14                6                  0      231
# CASIC                   2                0                  0        3
# CECLES                  3                0                  0        1
# CNES                    2                0                  0        6
# Douglas                 0                0                  0        1
# ...

# %%
df.describe()
# Out:
#        Organisation                                    Location  \
# count          4324                                        4324
# unique           56                                         137
# top       RVSN USSR  Site 31/6, Baikonur Cosmodrome, Kazakhstan
# freq           1777                                         235
#
#                               Date                               Detail  \
# count                         4324                                 4324
# unique                        4319                                 4278
# top     Wed Nov 05, 2008 00:15 UTC  Cosmos-3MRB (65MRB) | BOR-5 Shuttle
# freq                             2                                    6
#
#         Rocket_Status  Price Mission_Status
# count            4324    964           4324
# unique              2     56              4
# top     StatusRetired  450.0        Success
# freq             3534    136           3879

# %%
df.Mission_Status.unique()
# Out:
# array(['Success', 'Failure', 'Prelaunch Failure', 'Partial Failure'],
#       dtype=object)

# %%
df.Mission_Status.nunique()
# Out:
# 4

# %%
df.Rocket_Status.unique()
# Out:
# array(['StatusActive', 'StatusRetired'], dtype=object)

# %%
df.Rocket_Status.nunique()
# Out:
# 2

# %%
pd.crosstab(df.Organisation, df.Mission_Status, margins=True) # also give you sum of all columns and rows
# Out:
# Mission_Status    Failure  Partial Failure  Prelaunch Failure  Success   All
# Organisation
# AEB                     2                0                  1        0     3
# AMBA                    3                1                  0        4     8
# ASI                     0                0                  0        9     9
# Arianespace             7                3                  0      269   279
# Arm??e de l'Air         0                1                  0        3     4
# Blue Origin             0                0                  0       12    12
# Boeing                  3                2                  0      131   136
# CASC                   14                6                  0      231   251
# CASIC                   2                0                  0        3     5
# CECLES                  3                0                  0        1     4
# CNES                    2                0                  0        6     8
# ...

# %%
pd.crosstab(df.Organisation, df.Mission_Status, normalize="index", margins=True, dropna=True)
# Out:
# Mission_Status     Failure  Partial Failure  Prelaunch Failure   Success
# Organisation
# AEB               0.666667         0.000000           0.333333  0.000000
# AMBA              0.375000         0.125000           0.000000  0.500000
# ASI               0.000000         0.000000           0.000000  1.000000
# Arianespace       0.025090         0.010753           0.000000  0.964158
# Arm??e de l'Air   0.000000         0.250000           0.000000  0.750000
# Blue Origin       0.000000         0.000000           0.000000  1.000000
# Boeing            0.022059         0.014706           0.000000  0.963235
# CASC              0.055777         0.023904           0.000000  0.920319
# CASIC             0.400000         0.000000           0.000000  0.600000
# CECLES            0.750000         0.000000           0.000000  0.250000
# CNES              0.250000         0.000000           0.000000  0.750000
# Douglas           0.000000         0.000000           0.000000  1.000000
# ...

# %% [markdown]
# ## **Memory Management**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organisation    4324 non-null   object
#  1   Location        4324 non-null   object
#  2   Date            4324 non-null   object
#  3   Detail          4324 non-null   object
#  4   Rocket_Status   4324 non-null   object
#  5   Price           964 non-null    object
#  6   Mission_Status  4324 non-null   object
# dtypes: object(7)
# memory usage: 236.6+ KB

# %%
df.describe()
# Out:
#        Organisation                                    Location  \
# count          4324                                        4324
# unique           56                                         137
# top       RVSN USSR  Site 31/6, Baikonur Cosmodrome, Kazakhstan
# freq           1777                                         235
#
#                               Date                               Detail  \
# count                         4324                                 4324
# unique                        4319                                 4278
# top     Wed Nov 05, 2008 00:15 UTC  Cosmos-3MRB (65MRB) | BOR-5 Shuttle
# freq                             2                                    6
#
#         Rocket_Status  Price Mission_Status
# count            4324    964           4324
# unique              2     56              4
# top     StatusRetired  450.0        Success
# freq             3534    136           3879

# %%
df.info(verbose=False, memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Columns: 7 entries, Organisation to Mission_Status
# dtypes: object(7)
# memory usage: 2.1 MB

# %%
df.info(verbose=True, memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organisation    4324 non-null   object
#  1   Location        4324 non-null   object
#  2   Date            4324 non-null   object
#  3   Detail          4324 non-null   object
#  4   Rocket_Status   4324 non-null   object
#  5   Price           964 non-null    object
#  6   Mission_Status  4324 non-null   object
# dtypes: object(7)
# memory usage: 2.1 MB

# %%
org = set(df["Organisation"])

# %%
len(org)
# Out:
# 56

# %%
df.Organisation.nunique()
# Out:
# 56

# %%
df = pd.read_csv("../data/csvData/mission_launches.csv", nrows=100)
df
# Out:
#    Organisation                                           Location  \
# 0        SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1          CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2        SpaceX                      Pad A, Boca Chica, Texas, USA
# 3     Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ..          ...                                                ...
# 95          ILS       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 96         CASC       LC-9, Taiyuan Satellite Launch Center, China
# 97       VKS RF             Site 43/4, Plesetsk Cosmodrome, Russia
# 98    Roscosmos          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 99         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
#
#                           Date                                        Detail  \
# 0   Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# ...

# %%
df.memory_usage()
# Out:
# Index             128
# Organisation      800
# Location          800
# Date              800
# Detail            800
# Rocket_Status     800
# Price             800
# Mission_Status    800
# dtype: int64

# %%
df.info(verbose=True, memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organisation    100 non-null    object
#  1   Location        100 non-null    object
#  2   Date            100 non-null    object
#  3   Detail          100 non-null    object
#  4   Rocket_Status   100 non-null    object
#  5   Price           75 non-null     float64
#  6   Mission_Status  100 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 46.9 KB

# %% [markdown]
# ## **Time Series Analysis**
# - **pandas.to_datetime(arg, errors='raise', dayfirst=False, yearfirst=False, utc=False, format=None, exact=_NoDefault.no_default, unit=None, infer_datetime_format=_NoDefault.no_default, origin='unix', cache=True)pandas.to_datetime(arg, errors='raise', dayfirst=False, yearfirst=False, utc=False, format=None, exact=_NoDefault.no_default, unit=None, infer_datetime_format=_NoDefault.no_default, origin='unix', cache=True)**

# %%
df = pd.read_csv("../data/csvData/HistoricalData_1M.csv")
df
# Out:
#           Date Close/Last     Volume      Open       High        Low
# 0   05/05/2023    $173.57  113453200  $170.975    $174.30    $170.76
# 1   05/04/2023    $165.79   81235430   $164.89    $167.04    $164.31
# 2   05/03/2023    $167.45   65136020   $169.50    $170.92    $167.16
# 3   05/02/2023    $168.54   48425700   $170.09    $170.35    $167.54
# 4   05/01/2023    $169.59   52472940   $169.28    $170.45    $168.64
# 5   04/28/2023    $169.68   55275850   $168.49    $169.85  $167.8801
# 6   04/27/2023    $168.41   64902330   $165.19    $168.56    $165.19
# 7   04/26/2023    $163.76   45498800  $163.055    $165.28    $162.80
# 8   04/25/2023    $163.77   48714060   $165.19   $166.305    $163.73
# 9   04/24/2023    $165.33   41949580   $165.00    $165.60    $163.89
# 10  04/21/2023    $165.02   58337340   $165.05  $166.4521    $164.49
# 11  04/20/2023    $166.65   52456380   $166.09    $167.87    $165.56
# 12  04/19/2023    $167.63   47720170   $165.80    $168.16    $165.54
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
# df.set_index(columnName) # make a new index
df.set_index("Date", inplace=True)

# %%
# pandas.DataFrame.rename(columns={"old_column_name" : "new_column_name"})
# pandas.DataFrame.columns = ['your', 'new', 'column', 'names']
# pandas.DataFrame.set_axis(['your', 'new', 'column', 'names'2], axis=1)
df.columns=["price", "vol", "start", "max", "min"]
df
# Out:
#               price        vol     start        max        min
# Date
# 05/05/2023  $173.57  113453200  $170.975    $174.30    $170.76
# 05/04/2023  $165.79   81235430   $164.89    $167.04    $164.31
# 05/03/2023  $167.45   65136020   $169.50    $170.92    $167.16
# 05/02/2023  $168.54   48425700   $170.09    $170.35    $167.54
# 05/01/2023  $169.59   52472940   $169.28    $170.45    $168.64
# 04/28/2023  $169.68   55275850   $168.49    $169.85  $167.8801
# 04/27/2023  $168.41   64902330   $165.19    $168.56    $165.19
# 04/26/2023  $163.76   45498800  $163.055    $165.28    $162.80
# 04/25/2023  $163.77   48714060   $165.19   $166.305    $163.73
# 04/24/2023  $165.33   41949580   $165.00    $165.60    $163.89
# 04/21/2023  $165.02   58337340   $165.05  $166.4521    $164.49
# 04/20/2023  $166.65   52456380   $166.09    $167.87    $165.56
# 04/19/2023  $167.63   47720170   $165.80    $168.16    $165.54
# 04/18/2023  $166.47   49923010   $166.10    $167.41    $165.65
# ...

# %% [markdown]
# #### **Analysis with new dataset**

# %%
df = pd.read_csv("../data/csvData/HistoricalData_6M.csv")
df
# Out:
#            Date Close/Last     Volume      Open     High        Low
# 0    05/05/2023    $173.57  113453200  $170.975  $174.30    $170.76
# 1    05/04/2023    $165.79   81235430   $164.89  $167.04    $164.31
# 2    05/03/2023    $167.45   65136020   $169.50  $170.92    $167.16
# 3    05/02/2023    $168.54   48425700   $170.09  $170.35    $167.54
# 4    05/01/2023    $169.59   52472940   $169.28  $170.45    $168.64
# ..          ...        ...        ...       ...      ...        ...
# 118  11/14/2022    $148.28   73374110   $148.97  $150.28    $147.43
# 119  11/11/2022    $149.70   93979670   $145.82  $150.01    $144.37
# 120  11/10/2022    $146.87  118854000   $141.24  $146.87    $139.50
# 121  11/09/2022    $134.87   74917790   $138.50  $138.55  $134.5933
# 122  11/08/2022    $139.50   89908480   $140.41  $141.43    $137.49
#
# [123 rows x 6 columns]

# %%
df.rename(columns={"Close/Last":"Price"}, inplace=True)

# %%
df.set_index("Date", inplace=True)

# %%
df.index
# Out:
# Index(['05/05/2023', '05/04/2023', '05/03/2023', '05/02/2023', '05/01/2023',
#        '04/28/2023', '04/27/2023', '04/26/2023', '04/25/2023', '04/24/2023',
#        ...
#        '11/21/2022', '11/18/2022', '11/17/2022', '11/16/2022', '11/15/2022',
#        '11/14/2022', '11/11/2022', '11/10/2022', '11/09/2022', '11/08/2022'],
#       dtype='object', name='Date', length=123)

# %%
df.columns
# Out:
# Index(['Price', 'Volume', 'Open', 'High', 'Low'], dtype='object')

# %%
df.head(30)
# Out:
#               Price     Volume      Open       High        Low
# Date
# 05/05/2023  $173.57  113453200  $170.975    $174.30    $170.76
# 05/04/2023  $165.79   81235430   $164.89    $167.04    $164.31
# 05/03/2023  $167.45   65136020   $169.50    $170.92    $167.16
# 05/02/2023  $168.54   48425700   $170.09    $170.35    $167.54
# 05/01/2023  $169.59   52472940   $169.28    $170.45    $168.64
# 04/28/2023  $169.68   55275850   $168.49    $169.85  $167.8801
# 04/27/2023  $168.41   64902330   $165.19    $168.56    $165.19
# 04/26/2023  $163.76   45498800  $163.055    $165.28    $162.80
# 04/25/2023  $163.77   48714060   $165.19   $166.305    $163.73
# 04/24/2023  $165.33   41949580   $165.00    $165.60    $163.89
# 04/21/2023  $165.02   58337340   $165.05  $166.4521    $164.49
# 04/20/2023  $166.65   52456380   $166.09    $167.87    $165.56
# 04/19/2023  $167.63   47720170   $165.80    $168.16    $165.54
# 04/18/2023  $166.47   49923010   $166.10    $167.41    $165.65
# ...

# %%
df["04/24/2023":"03/28/2023"]
# Out:
#               Price    Volume      Open       High       Low
# Date
# 04/24/2023  $165.33  41949580   $165.00    $165.60   $163.89
# 04/21/2023  $165.02  58337340   $165.05  $166.4521   $164.49
# 04/20/2023  $166.65  52456380   $166.09    $167.87   $165.56
# 04/19/2023  $167.63  47720170   $165.80    $168.16   $165.54
# 04/18/2023  $166.47  49923010   $166.10    $167.41   $165.65
# 04/17/2023  $165.23  41516220   $165.09    $165.39   $164.03
# 04/14/2023  $165.21  49386480   $164.59    $166.32   $163.82
# 04/13/2023  $165.56  68445650   $161.63    $165.80   $161.42
# 04/12/2023  $160.10  50133060   $161.22    $162.06   $159.78
# 04/11/2023  $160.80  47644220   $162.35    $162.36   $160.51
# 04/10/2023  $162.03  47716880   $161.42    $162.03   $160.08
# 04/06/2023  $164.66  45390120   $162.43  $164.9584   $162.00
# 04/05/2023  $163.76  51511740   $164.74    $165.05   $161.80
# 04/04/2023  $165.63  46278300  $166.595    $166.84   $165.11
# ...

# %%
df.sort_index(ascending=False)
# Out:
#               Price     Volume      Open       High      Low
# Date
# 12/30/2022  $129.93   77034210   $128.41    $129.95  $127.43
# 12/29/2022  $129.61   75703710   $127.99  $130.4814  $127.73
# 12/28/2022  $126.04   85438390   $129.67  $131.0275  $125.87
# 12/27/2022  $130.03   69007830   $131.38    $131.41  $128.72
# 12/23/2022  $131.86   63814890   $130.92   $132.415  $129.64
# ...             ...        ...       ...        ...      ...
# 01/09/2023  $130.15   70790810  $130.465    $133.41  $129.89
# 01/06/2023  $129.62   87754720   $126.01    $130.29  $124.89
# 01/05/2023  $125.02   80962710   $127.13    $127.77  $124.76
# 01/04/2023  $126.36   89113630   $126.89  $128.6557  $125.08
# 01/03/2023  $125.07  112117500   $130.28    $130.90  $124.17
#
# [123 rows x 5 columns]

# %%
df[df.index>="12/23/2022"]
# Out:
#               Price    Volume     Open       High      Low
# Date
# 12/30/2022  $129.93  77034210  $128.41    $129.95  $127.43
# 12/29/2022  $129.61  75703710  $127.99  $130.4814  $127.73
# 12/28/2022  $126.04  85438390  $129.67  $131.0275  $125.87
# 12/27/2022  $130.03  69007830  $131.38    $131.41  $128.72
# 12/23/2022  $131.86  63814890  $130.92   $132.415  $129.64

# %%
# Retrive monthly dada
df.reset_index(inplace=True)

# %%
df
# Out:
#            Date    Price     Volume      Open     High        Low
# 0    05/05/2023  $173.57  113453200  $170.975  $174.30    $170.76
# 1    05/04/2023  $165.79   81235430   $164.89  $167.04    $164.31
# 2    05/03/2023  $167.45   65136020   $169.50  $170.92    $167.16
# 3    05/02/2023  $168.54   48425700   $170.09  $170.35    $167.54
# 4    05/01/2023  $169.59   52472940   $169.28  $170.45    $168.64
# ..          ...      ...        ...       ...      ...        ...
# 118  11/14/2022  $148.28   73374110   $148.97  $150.28    $147.43
# 119  11/11/2022  $149.70   93979670   $145.82  $150.01    $144.37
# 120  11/10/2022  $146.87  118854000   $141.24  $146.87    $139.50
# 121  11/09/2022  $134.87   74917790   $138.50  $138.55  $134.5933
# 122  11/08/2022  $139.50   89908480   $140.41  $141.43    $137.49
#
# [123 rows x 6 columns]

# %%
pd.DatetimeIndex(df['Date']).year
# Out:
# Int64Index([2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023,
#             ...
#             2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022],
#            dtype='int64', name='Date', length=123)
